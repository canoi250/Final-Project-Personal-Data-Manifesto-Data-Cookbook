# %%
from geopy.distance import geodesic
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np 
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm

# %%
air_pollution= pd.read_csv("air-pollution.csv")

# %%
air_pollution
# Out:
#        Nitrogen oxide (NOx)  Sulphur dioxide (SO₂)  Carbon monoxide (CO)  \
# 0                555.422173             139.417083          1.420733e+05
# 1                578.448831             145.094843          1.478592e+05
# 2                602.418601             150.990682          1.538674e+05
# 3                627.368479             157.111081          1.601044e+05
# 4                653.336678             163.462424          1.665768e+05
# ...                     ...                    ...                   ...
# 47530          83842.096401           67231.291799          1.610636e+06
# 47531          76234.430113           59452.695878          1.632515e+06
# 47532          74381.797266           53891.385836          1.657689e+06
# 47533          73062.525071           51072.778332          1.653665e+06
# 47534          70779.920495           45896.979630          1.647792e+06
#
#        Organic carbon (OC)         NMVOCs  Black carbon (BC)  Ammonia (NH₃)  \
# ...

# %%
max_value = air_pollution.loc[air_pollution["Entity"] == "Afghanistan", "Organic carbon (OC)"].max()

# %%
print("The highest organic carbon concentration is", max_value, ""
# Out:
# 42136.771901852495

# %%
max_values = air_pollution.groupby("Entity")["Organic carbon (OC)"].max()

# %%
max_values
# Out:
# Entity
# Afghanistan       4.213677e+04
# Africa            3.362257e+06
# Albania           1.112698e+04
# Algeria           9.731945e+04
# American Samoa    3.845587e+01
#                       ...
# Western Sahara    2.071036e+03
# World             1.401013e+07
# Yemen             8.800947e+03
# Zambia            8.046325e+04
# Zimbabwe          1.146132e+05
# Name: Organic carbon (OC), Length: 230, dtype: float64
